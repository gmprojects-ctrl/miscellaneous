# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
point = [1,-1]
x = np.linspace(0,400)
moves = [ point[np.random.randint(0,2)] for i in range(0,201) ]
position_1 = [ 0 + sum(moves[0:i]) for i in range(0,201) ]
moves = [ point[np.random.randint(0,2)] for i in range(0,201) ]
position_2 = [ 0 + sum(moves[0:i]) for i in range(0,201) ]
moves = [ point[np.random.randint(0,2)] for i in range(0,201) ]
position_3 = [ 0 + sum(moves[0:i]) for i in range(0,201) ]
moves = [ point[np.random.randint(0,2)] for i in range(0,201) ]
position_4 = [ 0 + sum(moves[0:i]) for i in range(0,201) ]
plt.grid(True)
plt.plot(position_1)
plt.plot(position_2)
plt.plot(position_3)
plt.plot(position_4)
plt.plot( np.sqrt(x))
plt.show()
